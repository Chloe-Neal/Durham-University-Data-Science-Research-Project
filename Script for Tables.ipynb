# %%
import pandas as pd
from nltk import word_tokenize
import re
from string import punctuation 
from nltk.corpus import stopwords
stopwords_english = stopwords.words('english') 
import numpy as np
import pandas as pd
from os import path
from PIL import Image
import wordcloud
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score,precision_score,recall_score,classification_report
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import svm
sns.set()

# %% [markdown]
# # Naive Bayes- Multinomial

# %%
import dataframe_image as dfi
import dataframe_image as dfi

df={}
df["Binary-classification"]= pd.DataFrame(columns = ["Class","Accuracy","Precision", "Recall","F1-Score"],
                         data = [["Total",'80%','78%', '80%', '79%'],
                                 ["False"," ",'89%', '79%', '84%'],
                                 ["True"," ",'68%','81%','74%'],
                                ["Unverified"," ", " ", " ", " "]]).set_index('Class')
pd.concat(df, axis=1)

df["Multi-classification"]= pd.DataFrame(columns = ["Class","Accuracy","Precision", "Recall","F1-Score"],
                         data = [["Total", '66%', '62%', '63%', '62%'],
                             ["False"," ",'85%', '76%', '80%'],
                                 ["True"," ",'53%', '58%', '55%'],
                                 ["Unverified"," ", '49%', '55%', '52%']]).set_index('Class')

df2 = pd.concat(df, axis=1)
#dfi.export(df2,"Multi Count %.png")
df2
# Out:
#            Binary-classification                            \
#                         Accuracy Precision Recall F1-Score
# Class
# Total                        80%       78%    80%      79%
# False                                  89%    79%      84%
# True                                   68%    81%      74%
# Unverified
#
#            Multi-classification
#                        Accuracy Precision Recall F1-Score
# Class
# Total                       66%       62%    63%      62%
# False                                 85%    76%      80%
# True                                  53%    58%      55%
# Unverified                            49%    55%      52%

# %% [markdown]
# # Naive Bayes- Bernoulli

# %%
import dataframe_image as dfi

df={}
df["2 Class"]= pd.DataFrame(columns = ["Class","Accuracy","Precision", "Recall","F1-Score"],
                         data = [["Total",0.82,0.81,0.78,0.79],
                                 ["False"," ",0.83, 0.91, 0.87],
                                 ["True"," ",0.79, 0.66,0.72],
                                ["Unverified"," ", " ", " ", " "]]).set_index('Class')
pd.concat(df, axis=1)

df["3 Class"]= pd.DataFrame(columns = ["Class","Accuracy","Precision", "Recall","F1-Score"],
                         data = [["Total", 0.69, 0.62, 0.64, 0.61],
                             ["False"," ",0.76, 0.89, 0.82],
                                 ["True"," ",0.61, 0.45, 0.52],
                                 ["Unverified"," ", 0.54, 0.48, 0.51]]).set_index('Class')

df2 = pd.concat(df, axis=1)
#dfi.export(df2,"Bernoulli Count.png")
df2
# Out:
#             2 Class                            3 Class                   \
#            Accuracy Precision Recall F1-Score Accuracy Precision Recall
# Class
# Total          0.82      0.81   0.78     0.79     0.69      0.62   0.64
# False                    0.83   0.91     0.87               0.76   0.89
# True                     0.79   0.66     0.72               0.61   0.45
# Unverified                                                  0.54   0.48
#
#
#            F1-Score
# Class
# Total          0.61
# False          0.82
# True           0.52
# Unverified     0.51

# %% [markdown]
# # KNN

# %%
import dataframe_image as dfi

df={}
df["Binary-classification(K = 27)"]= pd.DataFrame(columns = ["Class","Accuracy","Precision", "Recall","F1-Score"],
                         data = [["Total",'75%', '73%', '73%', '73%'],
                                 ["False"," ",'81%', '81%', '81%'],
                                 ["True"," ",'65%', '65%', '65%'],
                                ["Unverified"," ", " ", " ", " "]]).set_index('Class')
pd.concat(df, axis=1)

df["Multi-classification(K = 29)"]= pd.DataFrame(columns = ["Class","Accuracy","Precision", "Recall","F1-Score"],
                         data = [["Total", '63%', '57%', '57%', '57%'],
                             ["False"," ",'75%', '79%', '77%'],
                                 ["True"," ",'51%', '48%','49%'],
                                 ["Unverified"," ", '46%', '46%', '45%']]).set_index('Class')

df2 = pd.concat(df, axis=1)
#dfi.export(df2,"KNN Count%.png")
df2
# Out:
#            Binary-classification(K = 27)                            \
#                                 Accuracy Precision Recall F1-Score
# Class
# Total                                75%       73%    73%      73%
# False                                          81%    81%      81%
# True                                           65%    65%      65%
# Unverified
#
#            Multi-classification(K = 29)
#                                Accuracy Precision Recall F1-Score
# Class
# Total                               63%       57%    57%      57%
# False                                         75%    79%      77%
# True                                          51%    48%      49%
# Unverified                                    46%    46%      45%

# %% [markdown]
# # SVM

# %%
import dataframe_image as dfi

df={}
df["Binary-classification"]= pd.DataFrame(columns = ["Class","Accuracy","Precision", "Recall","F1-Score"],
                         data = [["Total",'82%', '80%', '80%', '80%'],
                                 ["False"," ",'86%', '85%', '86%'],
                                 ["True"," ",'73%','75%', '74%'],
                                ["Unverified"," ", " ", " ", " "]]).set_index('Class')
pd.concat(df, axis=1)

df["Multi-classification"]= pd.DataFrame(columns = ["Class","Accuracy","Precision", "Recall","F1-Score"],
                         data = [["Total", '68%', '63%', '62%', '62%'],
                             ["False"," ",'79%','83%', '81%'],
                                 ["True"," ",'58%', '53%', '55%'],
                                 ["Unverified"," ", '51%', '51%', '51%']]).set_index('Class')

df2 = pd.concat(df, axis=1)
#dfi.export(df2,"SVM count %.png")
df2
# Out:
#            Binary-classification                            \
#                         Accuracy Precision Recall F1-Score
# Class
# Total                        82%       80%    80%      80%
# False                                  86%    85%      86%
# True                                   73%    75%      74%
# Unverified
#
#            Multi-classification
#                        Accuracy Precision Recall F1-Score
# Class
# Total                       68%       63%    62%      62%
# False                                 79%    83%      81%
# True                                  58%    53%      55%
# Unverified                            51%    51%      51%

# %% [markdown]
# # Decision Tree

# %%
import dataframe_image as dfi

df={}
df["Binary-classification"]= pd.DataFrame(columns = ["Class","Accuracy","Precision", "Recall","F1-Score"],
                         data = [["Total",'72%', '69%', '67%', '68%'],
                                 ["False"," ",'76%','83%', '79%'],
                                 ["True"," ",'62%', '51%', '56%'],
                                ["Unverified"," ", " ", " ", " "]]).set_index('Class')
pd.concat(df, axis=1)

df["Multi-classification"]= pd.DataFrame(columns = ["Class","Accuracy","Precision", "Recall","F1-Score"],
                         data = [["Total", '58%', '52%', '51%', '52%'],
                             ["False"," ",'68%', '75%', '71%'],
                                 ["True"," ",'47%', '30%', '43%'],
                                 ["Unverified"," ", '42%', '39%', '40%']]).set_index('Class')

df2 = pd.concat(df, axis=1)
#dfi.export(df2,"Decision Tree count%.png")
df2
# Out:
#            Binary-classification                            \
#                         Accuracy Precision Recall F1-Score
# Class
# Total                        72%       69%    67%      68%
# False                                  76%    83%      79%
# True                                   62%    51%      56%
# Unverified
#
#            Multi-classification
#                        Accuracy Precision Recall F1-Score
# Class
# Total                       58%       52%    51%      52%
# False                                 68%    75%      71%
# True                                  47%    30%      43%
# Unverified                            42%    39%      40%

# %% [markdown]
# # Random Forest

# %%
import dataframe_image as dfi

df={}
df["Binary-classification"]= pd.DataFrame(columns = ["Class","Accuracy","Precision", "Recall","F1-Score"],
                         data = [["Total",'80%', '80%', '75%', '77%'],
                                 ["False"," ",'81%', '92%', '86%'],
                                 ["True"," ",'79%', '59%','67%'],
                                ["Unverified"," ", " ", " ", " "]]).set_index('Class')
pd.concat(df, axis=1)

df["Multi-classification"]= pd.DataFrame(columns = ["Class","Accuracy","Precision", "Recall","F1-Score"],
                         data = [["Total", '67%', '64%', '59%', '60%'],
                             ["False"," ",'71%', '91%', '80%'],
                                 ["True"," ",'64%', '40%', '49%'],
                                 ["Unverified"," ",'57%', '45%', '50%']]).set_index('Class')

df2 = pd.concat(df, axis=1)
#dfi.export(df2,"Random Forest Tree count%.png")
df2
# Out:
#            Binary-classification                            \
#                         Accuracy Precision Recall F1-Score
# Class
# Total                        80%       80%    75%      77%
# False                                  81%    92%      86%
# True                                   79%    59%      67%
# Unverified
#
#            Multi-classification
#                        Accuracy Precision Recall F1-Score
# Class
# Total                       67%       64%    59%      60%
# False                                 71%    91%      80%
# True                                  64%    40%      49%
# Unverified                            57%    45%      50%

# %% [markdown]
# # LSTM

# %%
import dataframe_image as dfi

df={}
df["Binary-classification"]= pd.DataFrame(columns = ["Class","Accuracy","Precision", "Recall","F1-Score"],
                         data = [["Total",'78%', '76%', '77%', '77%'],
                                 ["False"," ",'85%', '81%', '83%'],
                                 ["True"," ",'68%', '73%', '70%'],
                                ["Unverified"," ", " ", " ", " "]]).set_index('Class')
pd.concat(df, axis=1)

df["Multi-classification"]= pd.DataFrame(columns = ["Class","Accuracy","Precision", "Recall","F1-Score"],
                         data = [["Total", '62%', '56%', '56%', '56%'],
                             ["False"," ",'77%', '77%', '77%'],
                                 ["True"," ",'50%', '41%', '45%'],
                                 ["Unverified"," ", '42%', '51%', '46%']]).set_index('Class')

df2 = pd.concat(df, axis=1)
#dfi.export(df2,"LSTM count%.png")
df2
# Out:
#            Binary-classification                            \
#                         Accuracy Precision Recall F1-Score
# Class
# Total                        78%       76%    77%      77%
# False                                  85%    81%      83%
# True                                   68%    73%      70%
# Unverified
#
#            Multi-classification
#                        Accuracy Precision Recall F1-Score
# Class
# Total                       62%       56%    56%      56%
# False                                 77%    77%      77%
# True                                  50%    41%      45%
# Unverified                            42%    51%      46%

# %% [markdown]
# # CNN

# %%
import dataframe_image as dfi

df={}
df["Binary-classification"]= pd.DataFrame(columns = ["Class","Accuracy","Precision", "Recall","F1-Score"],
                         data = [["Total",'77%', '76%', '78%', '76%'],
                                 ["False"," ",'87%', '77%', '82%'],
                                 ["True"," ",'65%', '79%', '71%'],
                                ["Unverified"," ", " ", " ", " "]]).set_index('Class')
pd.concat(df, axis=1)

df["Multi-class Classification"]= pd.DataFrame(columns = ["Class","Accuracy","Precision", "Recall","F1-Score"],
                         data = [["Total", '61%', '54%', '52%','53%'],
                             ["False"," ",'69%', '84%', '76%'],
                                 ["True"," ",'50%', '39%', '44%'],
                                 ["Unverified"," ", '43%', '34%', '38%']]).set_index('Class')

df2 = pd.concat(df, axis=1)
#dfi.export(df2,"CNN count%.png")
df2
# Out:
#            Binary-classification                            \
#                         Accuracy Precision Recall F1-Score
# Class
# Total                        77%       76%    78%      76%
# False                                  87%    77%      82%
# True                                   65%    79%      71%
# Unverified
#
#            Multi-class Classification
#                              Accuracy Precision Recall F1-Score
# Class
# Total                             61%       54%    52%      53%
# False                                       69%    84%      76%
# True                                        50%    39%      44%
# Unverified                                  43%    34%      38%
